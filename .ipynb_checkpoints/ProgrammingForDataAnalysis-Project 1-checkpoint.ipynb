# %% [markdown]
# The study will investigate or explore 4 variables across a dataset of 100 customer. The variables of interest are:
#
# * Age (Continuous: 17-65)
# * Gender (Categorical: Male or female)
# * Region (Coninuous: 30-100)
# * Candidate

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib
import matplotlib.pyplot as plt

# %%
voters = np.random.choice(101, 100) 
voters_ages = np.random.randint(16, 70, 100)

# %%
plt.hist(voters_ages, edgecolor='k')
plt.title("Distribution of ages")
# Out:
# Text(0.5, 1.0, 'Distribution of ages')

# %%
np.mean(voters_ages, dtype=np.integer)
# Out:
# 39

# %%
region = (["North", "Midwest", "Southeast", "South", "Midwest" ]) 

df = pd.DataFrame(np.random.multinomial(100,[5/25.]*5, size=1)) 

df.columns = (["North", "Midwest", "Southeast", "South","Midwest"])

df.index = (["Total"])

print (df)
# Out:
#        North  Midwest  Southeast  South  Midwest
# Total     17       20         20     28       15

# %%
region = np.random.choice(["North", "Midwest", "Southeast", "South", "Midwest"], 100,
                         p=[0.15, 0.10, 0.35, 0.20, 0.20])
len(region)
# Out:
# 100

# %%
import seaborn as sns
sns.countplot(y=region, palette="Blues_d")
xlabel=('Number of customers')
plt.show()

# %%
gender = np.random.choice(["M","F"], 100, p=[0.54, 0.46]) 
len(gender)
# Out:
# 100

# %%
Candidate = (["Lula", "Bolsonaro"])

df = pd.DataFrame(np.random.multinomial(100,[1/2.]*2, size=1))

df.columns = (["Lula", "Bolsonaro"])

df.index = (["Total"])

print (df)
# Out:
#        Lula  Bolsonaro
# Total    58         42

# %%
df1 = pd.DataFrame(np.random.choice (region, 100))

df2 = pd.DataFrame(np.random.choice(gender, 100))

df3 = pd.DataFrame(voters_ages)
Candidate = (["Lula", "Bolsonaro"])

df4 = pd.DataFrame(np.random.choice (Candidate, 100))

#to merge df1, df2, df4, df4 together into one DataFrame
merged_df = pd.concat([df1, df2, df3, df4], axis=1)
pd.set_option('display.max_row', 100)
merged_df.columns = ["Region", "Gender", "Age", "Candidate"]
merged_df
# Out:
#        Region  Gender  Age  Candidate
# 0   Southeast  Female   34  Bolsonaro
# 1   Southeast    Male   17       Lula
# 2     Midwest  Female   30       Lula
# 3       South    Male   44       Lula
# 4       South  Female   66       Lula
# 5   Southeast    Male   62       Lula
# 6   Southeast  Female   50       Lula
# 7       North    Male   29       Lula
# 8       South    Male   61       Lula
# 9     Midwest  Female   32       Lula
# 10  Southeast    Male   52       Lula
# 11      South  Female   37       Lula
# 12      North  Female   59  Bolsonaro
# 13      South    Male   31       Lula
# 14      North    Male   59  Bolsonaro
# 15  Southeast    Male   46  Bolsonaro
# 16      South  Female   47  Bolsonaro
# 17      North  Female   56  Bolsonaro
# 18    Midwest  Female   27  Bolsonaro
# 19    Midwest  Female   49  Bolsonaro
# 20      South  Female   19       Lula
# 21      North  Female   54       Lula
# 22  Southeast    Male   47       Lula
# 23    Midwest    Male   54  Bolsonaro
# 24    Midwest  Female   46       Lula
