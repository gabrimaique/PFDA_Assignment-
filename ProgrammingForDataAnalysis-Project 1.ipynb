# %% [markdown]
# The study will investigate or explore 4 variables across a dataset of 100 customer. The variables of interest are:
#
# * Age (Continuous: 17-65)
# * Sex (Categorical: Male or female)
# * HDip grade (Coninuous: 30-100)
# **Hours per week study (Continuous: 0-40)

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
region = (["North", "Midwest", "Southeast", "South", "Midwest" ]) 

df = pd.DataFrame(np.random.multinomial(100,[5/25.]*5, size=1)) 

df.columns = (["North", "Midwest", "Southeast", "South","Midwest"])

df.index = (["Total"])

print (df)
# Out:
#        North  Midwest  Southeast  South  Midwest
# Total     19       22         25     15       19

# %%
gender = (["Male", "Female"])

df = pd.DataFrame(np.random.multinomial(100,[1/2.]*2, size=1))

df.columns = (["Male", "Female"])

df.index = (["Total"])

print (df)
# Out:
#        Male  Female
# Total    49      51

# %%
voters = np.random.choice(101, 100) 
voters_ages = np.random.randint(16, 70, 100)
sns.scatterplot(voters,voters_ages)
plt.xlabel("voters")
plt.ylabel("Age")
plt.show()
# Out:
# C:\Users\tirol\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
np.mean(voters, dtype=np.integer)
# Out:
# 50

# %%
Candidate = (["Lula", "Bolsonaro"])

df = pd.DataFrame(np.random.multinomial(100,[1/2.]*2, size=1))

df.columns = (["Lula", "Bolsonaro"])

df.index = (["Total"])

print (df)
# Out:
#        Lula  Bolsonaro
# Total    47         53

# %%
df1 = pd.DataFrame(np.random.choice (region, 100))

df2 = pd.DataFrame(np.random.choice(gender, 100))

df3 = pd.DataFrame(voters_ages)
Candidate = (["Lula", "Bolsonaro"])

df4 = pd.DataFrame(np.random.choice (Candidate, 100))

#to merge df1, df2, df4, df4 together into one DataFrame
merged_df = pd.concat([df1, df2, df3, df4], axis=1)
pd.set_option('display.max_row', 100)
merged_df.columns = ["Region", "Gender", "Age", "Candidate"]
merged_df
# Out:
#        Region  Gender  Age  Candidate
# 0   Southeast  Female   47  Bolsonaro
# 1     Midwest    Male   17       Lula
# 2     Midwest    Male   56  Bolsonaro
# 3     Midwest  Female   37       Lula
# 4   Southeast  Female   18  Bolsonaro
# 5       South    Male   68  Bolsonaro
# 6   Southeast  Female   25       Lula
# 7       North  Female   41       Lula
# 8     Midwest  Female   32       Lula
# 9       North  Female   54  Bolsonaro
# 10    Midwest    Male   37       Lula
# 11      North  Female   50  Bolsonaro
# 12      South  Female   44  Bolsonaro
# 13    Midwest    Male   34       Lula
# 14    Midwest  Female   22  Bolsonaro
# 15  Southeast    Male   27       Lula
# 16  Southeast    Male   26  Bolsonaro
# 17    Midwest  Female   28       Lula
# 18      North  Female   33  Bolsonaro
# 19      South  Female   54       Lula
# 20    Midwest    Male   51       Lula
# 21      South    Male   19       Lula
# 22      South  Female   54  Bolsonaro
# 23      South    Male   20       Lula
# 24    Midwest    Male   29       Lula
# 25    Midwest  Female   56       Lula
# 26      South    Male   16  Bolsonaro
# 27      South  Female   55       Lula
# 28    Midwest    Male   39       Lula
# 29      South  Female   58       Lula
# 30      South    Male   33       Lula
# 31      South    Male   52  Bolsonaro
# 32      North  Female   55       Lula
# 33    Midwest    Male   65  Bolsonaro
# 34      North  Female   45  Bolsonaro
# 35  Southeast    Male   34  Bolsonaro
# 36    Midwest    Male   55       Lula
# 37  Southeast    Male   24  Bolsonaro
# 38    Midwest    Male   19       Lula
# 39    Midwest  Female   44  Bolsonaro
# 40      North  Female   61       Lula
# 41      South  Female   49       Lula
# 42    Midwest    Male   38  Bolsonaro
# 43    Midwest    Male   22       Lula
# 44      North    Male   33       Lula
# 45  Southeast  Female   22  Bolsonaro
# 46      North  Female   24  Bolsonaro
# 47    Midwest  Female   64       Lula
# 48    Midwest    Male   68  Bolsonaro
# 49      North  Female   37  Bolsonaro
# 50      South    Male   66  Bolsonaro
# 51  Southeast    Male   21       Lula
# 52      South  Female   19       Lula
# 53  Southeast  Female   16  Bolsonaro
# 54  Southeast    Male   37       Lula
# 55    Midwest    Male   49       Lula
# 56    Midwest    Male   53  Bolsonaro
# 57    Midwest  Female   31       Lula
# 58      North  Female   25  Bolsonaro
# 59    Midwest    Male   69       Lula
# 60    Midwest    Male   57  Bolsonaro
# 61      North    Male   32       Lula
# 62      South  Female   30       Lula
# 63    Midwest  Female   57  Bolsonaro
# 64  Southeast    Male   48  Bolsonaro
# 65      North  Female   16  Bolsonaro
# 66      North    Male   61  Bolsonaro
# 67      South    Male   28  Bolsonaro
# 68    Midwest  Female   20  Bolsonaro
# 69      South  Female   17       Lula
# 70    Midwest  Female   27       Lula
# 71      South    Male   65       Lula
# 72      South  Female   43       Lula
# 73      North  Female   22  Bolsonaro
# 74    Midwest  Female   50       Lula
# 75  Southeast  Female   36       Lula
# 76    Midwest    Male   54  Bolsonaro
# 77    Midwest  Female   52  Bolsonaro
# 78    Midwest  Female   41  Bolsonaro
# 79      South  Female   62  Bolsonaro
# 80      South  Female   23       Lula
# 81  Southeast  Female   20  Bolsonaro
# 82    Midwest  Female   32       Lula
# 83      North  Female   47       Lula
# 84  Southeast    Male   43  Bolsonaro
# 85  Southeast    Male   28  Bolsonaro
# 86    Midwest    Male   34  Bolsonaro
# 87    Midwest  Female   38       Lula
# 88      South  Female   26  Bolsonaro
# 89      South  Female   62       Lula
# 90      North  Female   65  Bolsonaro
# 91    Midwest  Female   31       Lula
# 92      South  Female   58       Lula
# 93  Southeast    Male   47       Lula
# 94  Southeast  Female   21  Bolsonaro
# 95  Southeast  Female   52  Bolsonaro
# 96    Midwest  Female   56       Lula
# 97      South    Male   25       Lula
# 98    Midwest  Female   52  Bolsonaro
# 99      South  Female   59  Bolsonaro
