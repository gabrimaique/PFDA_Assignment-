# %% [markdown]
# # Programming for Data Analysis Assignment 2022
#
# ### 1. Introduction
#
# The goal of this project is to use a synthesised data set to measure a real-world event using four different variables across 100 data points.
#
# Brazil just held a presidential election, and the goal of this study is to attempt to comprehend Brazilian society and discover the reasons why some Brazilians favour one candidate over another.
#
# The worker's party candidate in Brazil, Lula, won the election. I'll highlight some interesting aspects of Brazilian society and explain why people from various social classes supported him.
#
# The variables selected to represent the data for this project, which is based on the concept of 100 voters, are as follows:
#
# 1. Age
# 2. Gender
# 3. Region
# 4. Social Class

# %%
# first we have to import the libraries to run the code and perform analysis
import numpy as np # library that facilitates efficient numerical operations on large quantities of data
import pandas as pd #Python package that is most widely used for data science/data analysis and machine learning tasks.
import seaborn as sns #library for making statistical graphics in Python
from scipy.stats import norm #solve scientific and mathematical problems.
import matplotlib.pyplot as plt #library for creating static, animated, and interactive visualizations

# %% [markdown]
# # Variables
# ## Age

# %%
np.random.seed(12345)
voters_age = np.random.randint(low=16, high=70, size=100) 
print (voters_age)
# Out:
# [50 53 45 17 52 57 53 50 45 17 65 30 57 43 32 66 25 27 29 26 33 34 54 23
#  59 55 39 45 47 49 43 39 52 16 63 19 21 31 27 30 67 33 59 21 50 69 67 24
#  21 50 60 21 35 28 30 32 43 54 40 48 59 21 26 28 38 28 57 34 66 34 62 39
#  37 23 33 16 42 60 30 42 59 46 51 48 19 16 22 18 65 60 53 24 59 38 37 17
#  48 21 56 66]

# %%
plt.hist(voters_age, edgecolor='k')
plt.title("Distribution of ages")
# Out:
# Text(0.5, 1.0, 'Distribution of ages')

# %%
np.mean(voters_age, dtype=np.integer)
# Out:
# 40

# %%
df1 = pd.DataFrame(data=voters_age, columns=["voters_age"])
df1
# Out:
#     voters_age
# 0           50
# 1           53
# 2           45
# 3           17
# 4           52
# ..         ...
# 95          17
# 96          48
# 97          21
# 98          56
# 99          66
#
# [100 rows x 1 columns]

# %%
df1.describe()
# Out:
#        voters_age
# count  100.000000
# mean    40.680000
# std     15.491855
# min     16.000000
# 25%     27.750000
# 50%     39.500000
# 75%     53.250000
# max     69.000000

# %%
np.random.seed(12345)
gender = ['Male', 'Female'] 
voters_gender = np.random.choice(gender, 100, p=[0.49, 0.51])
print(voters_gender)
# Out:
# ['Female' 'Male' 'Male' 'Male' 'Female' 'Female' 'Female' 'Female'
#  'Female' 'Female' 'Female' 'Female' 'Male' 'Male' 'Male' 'Female'
#  'Female' 'Female' 'Female' 'Female' 'Female' 'Female' 'Male' 'Male'
#  'Male' 'Female' 'Female' 'Female' 'Female' 'Male' 'Male' 'Female'
#  'Female' 'Male' 'Female' 'Female' 'Female' 'Male' 'Female' 'Female'
#  'Female' 'Female' 'Female' 'Male' 'Male' 'Male' 'Male' 'Male' 'Female'
#  'Male' 'Female' 'Male' 'Female' 'Female' 'Female' 'Male' 'Male' 'Male'
#  'Female' 'Female' 'Male' 'Male' 'Female' 'Male' 'Male' 'Female' 'Female'
#  'Female' 'Female' 'Female' 'Female' 'Female' 'Male' 'Female' 'Female'
#  'Male' 'Male' 'Female' 'Female' 'Female' 'Female' 'Female' 'Male'
#  'Female' 'Male' 'Female' 'Male' 'Male' 'Female' 'Male' 'Female' 'Female'
#  'Female' 'Female' 'Male' 'Female' 'Male' 'Female' 'Female' 'Male']

# %%
df2 = pd.DataFrame(data=voters_gender, columns=["Gender"])
df2
# Out:
#     Gender
# 0   Female
# 1     Male
# 2     Male
# 3     Male
# 4   Female
# ..     ...
# 95  Female
# 96    Male
# 97  Female
# 98  Female
# 99    Male
#
# [100 rows x 1 columns]

# %%
df2.describe()
# Out:
#         Gender
# count      100
# unique       2
# top     Female
# freq        62

# %%
labels = ["Southeast", "Northeast", "North", "South", "Midwest"]
means = [0.40, 0.25, 0.10, 0.15, 0.10 ]
x = np.arange(len(labels))
width = 0.75

ax = plt.subplot()
rects = ax.bar(x, means, width)
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_title("Population Distribution")
# Out:
# Text(0.5, 1.0, 'Population Distribution')

# %%
np.random.seed(12345)
region = ["Southeast", "Northeast", "North", "South", "Midwest"]
population_distribution = np.random.choice(region, 100, p=[0.40, 0.25, 0.10, 0.15, 0.10 ])
print(population_distribution)
# Out:
# ['Midwest' 'Southeast' 'Southeast' 'Southeast' 'Northeast' 'Northeast'
#  'Midwest' 'North' 'North' 'North' 'North' 'Midwest' 'Southeast'
#  'Southeast' 'Southeast' 'North' 'South' 'South' 'Midwest' 'North'
#  'Northeast' 'North' 'Northeast' 'Southeast' 'Northeast' 'North' 'Midwest'
#  'North' 'South' 'Southeast' 'Southeast' 'South' 'Midwest' 'Southeast'
#  'Northeast' 'Northeast' 'Northeast' 'Southeast' 'South' 'North' 'South'
#  'Northeast' 'South' 'Southeast' 'Southeast' 'Southeast' 'Northeast'
#  'Northeast' 'North' 'Southeast' 'Northeast' 'Southeast' 'South' 'Midwest'
#  'Northeast' 'Southeast' 'Northeast' 'Southeast' 'South' 'Midwest'
#  'Southeast' 'Southeast' 'Northeast' 'Southeast' 'Southeast' 'North'
#  'South' 'Northeast' 'Midwest' 'Northeast' 'South' 'Northeast' 'Southeast'
#  'North' 'Northeast' 'Southeast' 'Southeast' 'South' 'Northeast' 'Midwest'
#  'Midwest' 'Northeast' 'Southeast' 'North' 'Southeast' 'Northeast'
#  'Southeast' 'Southeast' 'North' 'Southeast' 'South' 'South' 'South'
#  'Midwest' 'Southeast' 'Midwest' 'Southeast' 'South' 'South' 'Southeast']

# %%
df3 = pd.DataFrame(data=population_distribution, columns=["population_distribution"])
df3
# Out:
#    population_distribution
# 0                  Midwest
# 1                Southeast
# 2                Southeast
# 3                Southeast
# 4                Northeast
# ..                     ...
# 95                 Midwest
# 96               Southeast
# 97                   South
# 98                   South
# 99               Southeast
#
# [100 rows x 1 columns]

# %%
df3.describe()
# Out:
#        population_distribution
# count                      100
# unique                       5
# top                  Southeast
# freq                        33

# %%
labels = ["A", "B", "C", "D and E"]
means = [0.05, 0.10, 0.35, 0.50 ]
x = np.arange(len(labels))
width = 0.75

ax = plt.subplot()
rects = ax.bar(x, means, width)
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_title("Social Class Distribution")
# Out:
# Text(0.5, 1.0, 'Social Class Distribution')

# %%
np.random.seed(12345)
social_class = ["A", "B", "C", "DE"]
social_class_distribution = np.random.choice(social_class, 100, p=[0.05, 0.10, 0.35, 0.50 ])
print(social_class_distribution)
# Out:
# ['DE' 'C' 'C' 'C' 'DE' 'DE' 'DE' 'DE' 'DE' 'DE' 'DE' 'DE' 'A' 'B' 'C' 'DE'
#  'DE' 'DE' 'DE' 'DE' 'DE' 'DE' 'C' 'C' 'C' 'DE' 'DE' 'DE' 'DE' 'C' 'A'
#  'DE' 'DE' 'A' 'C' 'DE' 'DE' 'B' 'DE' 'DE' 'DE' 'DE' 'DE' 'B' 'C' 'C' 'C'
#  'C' 'DE' 'C' 'DE' 'C' 'DE' 'DE' 'DE' 'C' 'C' 'C' 'DE' 'DE' 'C' 'C' 'DE'
#  'C' 'B' 'DE' 'DE' 'DE' 'DE' 'DE' 'DE' 'C' 'C' 'DE' 'DE' 'C' 'C' 'DE' 'C'
#  'DE' 'DE' 'DE' 'C' 'DE' 'C' 'C' 'C' 'C' 'DE' 'C' 'DE' 'DE' 'DE' 'DE' 'B'
#  'DE' 'C' 'DE' 'DE' 'A']

# %%
df4 = pd.DataFrame(data=social_class_distribution, columns=["social_class_distribution"])
df4
# Out:
#    social_class_distribution
# 0                         DE
# 1                          C
# 2                          C
# 3                          C
# 4                         DE
# ..                       ...
# 95                        DE
# 96                         C
# 97                        DE
# 98                        DE
# 99                         A
#
# [100 rows x 1 columns]

# %%
df4.describe()
# Out:
#        social_class_distribution
# count                        100
# unique                         4
# top                           DE
# freq                          58

# %%
merged_df = pd.concat([df4, df1, df2, df3], axis=1)
pd.set_option('display.max_row', 100)
merged_df.columns = ["Social Class", "Voters Age", "Gender", "Region"]
merged_df
# Out:
#    Social Class  Voters Age  Gender     Region
# 0            DE          50  Female    Midwest
# 1             C          53    Male  Southeast
# 2             C          45    Male  Southeast
# 3             C          17    Male  Southeast
# 4            DE          52  Female  Northeast
# 5            DE          57  Female  Northeast
# 6            DE          53  Female    Midwest
# 7            DE          50  Female      North
# 8            DE          45  Female      North
# 9            DE          17  Female      North
# 10           DE          65  Female      North
# 11           DE          30  Female    Midwest
# 12            A          57    Male  Southeast
# 13            B          43    Male  Southeast
# 14            C          32    Male  Southeast
# 15           DE          66  Female      North
# 16           DE          25  Female      South
# 17           DE          27  Female      South
# 18           DE          29  Female    Midwest
# 19           DE          26  Female      North
# 20           DE          33  Female  Northeast
# 21           DE          34  Female      North
# 22            C          54    Male  Northeast
# 23            C          23    Male  Southeast
# 24            C          59    Male  Northeast
# 25           DE          55  Female      North
# 26           DE          39  Female    Midwest
# 27           DE          45  Female      North
# 28           DE          47  Female      South
# 29            C          49    Male  Southeast
# 30            A          43    Male  Southeast
# 31           DE          39  Female      South
# 32           DE          52  Female    Midwest
# 33            A          16    Male  Southeast
# 34            C          63  Female  Northeast
# 35           DE          19  Female  Northeast
# 36           DE          21  Female  Northeast
# 37            B          31    Male  Southeast
# 38           DE          27  Female      South
# 39           DE          30  Female      North
# 40           DE          67  Female      South
# 41           DE          33  Female  Northeast
# 42           DE          59  Female      South
# 43            B          21    Male  Southeast
# 44            C          50    Male  Southeast
# 45            C          69    Male  Southeast
# 46            C          67    Male  Northeast
# 47            C          24    Male  Northeast
# 48           DE          21  Female      North
# 49            C          50    Male  Southeast
# 50           DE          60  Female  Northeast
# 51            C          21    Male  Southeast
# 52           DE          35  Female      South
# 53           DE          28  Female    Midwest
# 54           DE          30  Female  Northeast
# 55            C          32    Male  Southeast
# 56            C          43    Male  Northeast
# 57            C          54    Male  Southeast
# 58           DE          40  Female      South
# 59           DE          48  Female    Midwest
# 60            C          59    Male  Southeast
# 61            C          21    Male  Southeast
# 62           DE          26  Female  Northeast
# 63            C          28    Male  Southeast
# 64            B          38    Male  Southeast
# 65           DE          28  Female      North
# 66           DE          57  Female      South
# 67           DE          34  Female  Northeast
# 68           DE          66  Female    Midwest
# 69           DE          34  Female  Northeast
# 70           DE          62  Female      South
# 71            C          39  Female  Northeast
# 72            C          37    Male  Southeast
# 73           DE          23  Female      North
# 74           DE          33  Female  Northeast
# 75            C          16    Male  Southeast
# 76            C          42    Male  Southeast
# 77           DE          60  Female      South
# 78            C          30  Female  Northeast
# 79           DE          42  Female    Midwest
# 80           DE          59  Female    Midwest
# 81           DE          46  Female  Northeast
# 82            C          51    Male  Southeast
# 83           DE          48  Female      North
# 84            C          19    Male  Southeast
# 85            C          16  Female  Northeast
# 86            C          22    Male  Southeast
# 87            C          18    Male  Southeast
# 88           DE          65  Female      North
# 89            C          60    Male  Southeast
# 90           DE          53  Female      South
# 91           DE          24  Female      South
# 92           DE          59  Female      South
# 93           DE          38  Female    Midwest
# 94            B          37    Male  Southeast
# 95           DE          17  Female    Midwest
# 96            C          48    Male  Southeast
# 97           DE          21  Female      South
# 98           DE          56  Female      South
# 99            A          66    Male  Southeast
